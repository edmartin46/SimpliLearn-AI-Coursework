# %%
pip install -U "autogen-agentchat" "autogen-ext[openai]"
# Out:
# Collecting autogen-agentchat
#   Downloading autogen_agentchat-0.7.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting autogen-ext[openai]
#   Downloading autogen_ext-0.7.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting autogen-core==0.7.5 (from autogen-agentchat)
#   Downloading autogen_core-0.7.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonref~=1.1.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat) (1.34.1)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat) (12.2.0)
# Requirement already satisfied: protobuf~=5.29.3 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat) (5.29.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\edmar\appdata\roaming\python\python312\site-packages (from autogen-core==0.7.5->autogen-agentchat) (4.15.0)
# Requirement already satisfied: aiofiles in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-ext[openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-ext[openai]) (2.41.1)
# Requirement already satisfied: tiktoken>=0.8.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from autogen-ext[openai]) (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.93->autogen-ext[openai]) (4.68.2)
# Requirement already satisfied: regex in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2026.1.15)
# Requirement already satisfied: requests in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from tiktoken>=0.8.0->autogen-ext[openai]) (2.34.2)
# Requirement already satisfied: idna>=2.8 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[openai]) (3.18)
# Requirement already satisfied: certifi in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[openai]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-agentchat) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat) (0.4.2)
# Requirement already satisfied: colorama in c:\users\edmar\appdata\roaming\python\python312\site-packages (from tqdm>4->openai>=1.93->autogen-ext[openai]) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from requests->tiktoken>=0.8.0->autogen-ext[openai]) (2.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\edmar\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-agentchat) (4.1.0)
# Downloading autogen_agentchat-0.7.5-py3-none-any.whl (119 kB)
# Downloading autogen_core-0.7.5-py3-none-any.whl (101 kB)
# Downloading autogen_ext-0.7.5-py3-none-any.whl (331 kB)
# Installing collected packages: autogen-core, autogen-ext, autogen-agentchat
# Successfully installed autogen-agentchat-0.7.5 autogen-core-0.7.5 autogen-ext-0.7.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import asyncio 
import os 
from autogen_core.models import UserMessage 
from autogen_ext.models.openai import OpenAIChatCompletionClient 
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model_client = OpenAIChatCompletionClient( 
        model="gpt-5-mini", 
        api_key=os.getenv("OPENAI_API_KEY")
    ) 
response = await model_client.create([ 
    UserMessage( 
        content="What is Microsoft AutoGen?", 
        source="user" 
    ) 
]) 

print(response.content) 

await model_client.close()
# Out:
# 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
# Microsoft AutoGen is an open-source framework from Microsoft for building, orchestrating, simulating and deploying multi-agent AI systems — i.e., systems made up of multiple collaborating agents (LLM-based assistants, specialized workers, tool-callers, supervisors, etc.) rather than a single conversational model. It’s designed to make it easier to compose agents, tools, memory, planners and runtime orchestration into more capable, long-running or complex workflows.
#
# Key ideas and capabilities
# - Multi-agent orchestration: first-class support for multiple agents with different roles and communication patterns (peer-to-peer, supervisor/worker, requester/responder).
# - Tool integration: agents can call external tools, APIs, or custom code and incorporate tool outputs into reasoning and planning.
# - Memory and state: built-in support for conversation histories and persistent memory so agents can remember and reuse context across turns or sessions.
# - Planning and coordination: primitives for task decomposition, planning, and coordinating sub-tasks among agents.
# - Simulation and evaluation: facilities to run multi-agent simulations for testing, debugging and measuring behavior before deployment.
# - Extensible LLM/backends: integrates with common model providers (OpenAI, Azure OpenAI and others) so you can plug in the LLMs you prefer.
# - Deployment-oriented: features to support longer-running agents, human-in-the-loop interventions, and production-like workflows.
#
# Typical uses
# - Orchestrating specialist agents for complex tasks (e.g., research agent + summarizer + code generator).
# - Autonomous workflows that require tool usage (APIs, DBs, web search) and multi-step planning.
# - Simulating multi-agent interactions (negotiation, user/assistant/test scenarios).
# - Building customer support systems with supervisor & worker agents, or pipelines that call multiple microservices.
#
# How it differs from single-agent libraries
# - Unlike single-agent/chat frameworks (or simple chains), AutoGen focuses on interactions among multiple agents and on higher-level coordination and orchestration patterns. It’s complementary to other tool/chain libraries — you can often use them together.
#
# Getting started
# - The project is open-source with examples and docs on its repo/website (look for Microsoft’s AutoGen repo). Start by exploring the examples that show multi-agent conversations, tool use, and planner patterns, then adapt agents and tools to your LLM and runtime environment.
#
# If you want, I can:
# - Point you to the official GitHub/docs (give me permission to fetch the exact link), or
# - Show a short conceptual example (two agents collaborating to solve a task), or
# - Compare AutoGen to a specific alternative (LangChain, Ray, etc.).
